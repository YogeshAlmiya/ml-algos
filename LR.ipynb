# %%
import numpy as np
import pandas as pd
from pandas import Series
from pandas import DataFrame

# %%
#!pip install notebook --upgrade
# !pip install --upgrade pip --user
# Out:
# Requirement already up-to-date: pip in c:\users\oii\anaconda3\lib\site-packages (19.3.1)

# %%
from sklearn.model_selection import train_test_split

#import train and test files
train=pd.read_csv("D:/bm/train.csv")
test=pd.read_csv("D:/bm/test.csv")

# %%
train.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15     9.300000          Low Fat         0.016047
# 1           DRC01     5.920000          Regular         0.019278
# 2           FDN15    17.500000          Low Fat         0.016760
# 3           FDX07    19.200000          Regular         0.000000
# 4           NCD19     8.930000          Low Fat         0.000000
# 5           FDP36    10.395000          Regular         0.000000
# 6           FDO10    13.650000          Regular         0.012741
# 7           FDP10    12.695633          Low Fat         0.127470
# 8           FDH17    16.200000          Regular         0.016687
# 9           FDU28    19.200000          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
#est.head(20)
test.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
#test.isnull().sum()
test['Item_Weight'].fillna((test['Item_Weight'].mean()), inplace=True)
test["Outlet_Size"].fillna("Medium",inplace=True)
train['Item_Weight'].fillna((train['Item_Weight'].mean()), inplace=True)
train["Outlet_Size"].fillna("Medium",inplace=True)

# %%
#import linear regression from sklearn
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()

# %%
#splitting nto training and into cv for cross validation
X=train.iloc[:,[5,7]]
x_train,x_cv,y_train,y_cv=train_test_split(X,train.Item_Outlet_Sales)
print(X)
# Out:
#       Item_MRP  Outlet_Establishment_Year
# 0     249.8092                       1999
# 1      48.2692                       2009
# 2     141.6180                       1999
# 3     182.0950                       1998
# 4      53.8614                       1987
# 5      51.4008                       2009
# 6      57.6588                       1987
# 7     107.7622                       1985
# 8      96.9726                       2002
# 9     187.8214                       2007
# 10     45.5402                       1999
# 11    144.1102                       1997
# 12    145.4786                       1999
# 13    119.6782                       1997
# 14    196.4426                       1987
# 15     56.3614                       1997
# 16    115.3492                       2009
# 17     54.3614                       1999
# 18    113.2834                       1985
# 19    230.5352                       2004
# 20    250.8724                       1987
# ...

# %%
#train model
lreg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
pred = lreg.predict(x_cv)
print(pred)
# Out:
# [ 3171.76860298  2363.55346019  1588.29795969 ...,  2941.61511044
#   1877.62185402  1264.50206793]

# %%
mse = np.mean((pred - y_cv)**2)
print(mse)
# Out:
# 1868769.7758976712

# %%
rms=np.sqrt(np.mean(np.power((np.array(target-pred),2))
